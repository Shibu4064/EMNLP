# %% [markdown]
# <a href="https://colab.research.google.com/github/Shibu4064/EMNLP/blob/main/merging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/EMNLP/train.csv")
df.drop('label', inplace=True, axis=1)
df
# Out:
#                                                    text
# 0     যে দেশে সন্ত্রাসরা দেশ চালায়সে দেশে শান্তি কিভ...
# 1     এই বিচার শেষ বিচার নয়।আসল বিচার হবে আল্লাহর আদ...
# 2     আরব দেশগুলোকে বলব ভারতের সাথে সব ব্যবসা বাণিজ্...
# 3                                       দেশটা সুস্থ নাই
# 4     আপনার কথা দুঃখ জনক আগে বিডিও থাকলে কেন ধরা হলন...
# ...                                                 ...
# 2695       হল বন্ধ করার আগে নিউমার্কেট বন্ধ করা উচিৎ,,।
# 2696  এ স্বাধীন দেশে ভোটটা অন্ততঃ আমাদের দিতে দেন।জা...
# 2697  আল হামদুলিল্লাহ্...প্রিয় ভিউয়ার্স আপনাদের ভালব...
# 2698        এই গুলা ত বিচার করবায় ঐ তোমরা ত ইন্ডিয়ান না
# 2699  ফি আমানিল্লাহ। বাংলার জমিনে হযরত মুহাম্মদ সাঃ ...
#
# [2700 rows x 1 columns]

# %%
df1=pd.read_csv("/content/drive/MyDrive/EMNLP/to be merged/negative_sentiment.csv")
df1
# Out:
#                                                    text
# 0             আমার জীবনের সবথেকে ফালতু একটা নাটক এইটা\n
# 1      সাধারণ মানুষ টিভি চ্যানেল গুলো ছুড়ে ফেলে দিয়...
# 2                     স্টুডেন্ট ওরে একটা থাপ্পড় মারো\n
# 3      নাটকটিতে কথা থেকে মিউজিকের সাউন্ডটা বেশি হয়ে ...
# 4                              পাকনা মেয়াটা একটা বাজে\n
# ...                                                 ...
# 3302                                  পালতু নাটক একটা\n
# 3303                               ফালতু, আলতু, টালতু\n
# 3304                                শালা আসোলেই পেটুক\n
# 3305                                    বেহাইয়া জামাই\n
# 3306                   নতুন অভিনয়শিল্পী। অভারএ্যাকটিং\n
#
# [3307 rows x 1 columns]

# %%
df1.text.str.decode('unicode_escape')
df1
# Out:
#                                                    text
# 0             আমার জীবনের সবথেকে ফালতু একটা নাটক এইটা\n
# 1      সাধারণ মানুষ টিভি চ্যানেল গুলো ছুড়ে ফেলে দিয়...
# 2                     স্টুডেন্ট ওরে একটা থাপ্পড় মারো\n
# 3      নাটকটিতে কথা থেকে মিউজিকের সাউন্ডটা বেশি হয়ে ...
# 4                              পাকনা মেয়াটা একটা বাজে\n
# ...                                                 ...
# 3302                                  পালতু নাটক একটা\n
# 3303                               ফালতু, আলতু, টালতু\n
# 3304                                শালা আসোলেই পেটুক\n
# 3305                                    বেহাইয়া জামাই\n
# 3306                   নতুন অভিনয়শিল্পী। অভারএ্যাকটিং\n
#
# [3307 rows x 1 columns]

# %%
df2=pd.read_csv("/content/drive/MyDrive/EMNLP/Final_data.csv")
df2
# Out:
#                                                    Text  label
# 0     ইসলামের সচেতন সৈনিক,কুত্তার বাচ্চা, তোদের শিক্...    1.0
# 1                                     ধর্ম মানে অশান্তি    1.0
# 2     হিন্দু প্রকারভেদ।  রাধাকৃষ্ণ  কৃষ্ণ_কৃষ্ণ বুঝল...    1.0
# 3     সালা তুই একটা হিন্দুর বাচ্চা , নামের পরে খান ল...    2.0
# 4                  হিন্দুদের দেশ বাংলাদেশ। জয় শ্রী রাম    1.0
# ...                                                 ...    ...
# 6526  পুরুষ তার নিজের যৌন-উত্তেজনা সামাল দেবার শিক্ষ...    2.0
# 6527  সব দোষ দিপুর! কিন্তু বিবাহিত লুচ্চা নারীগুলা এ...    2.0
# 6528    মেয়েরা অনেক লোভী তাই এদের কপালে এমনটা লেখা ছিল    1.0
# 6529               মহিলারা বেশি লোভি তাই বুজতে পারে নাই    2.0
# 6530               নারী তুই কলঙ্কিনী নারী তুই জাহান্নমী    2.0
#
# [6531 rows x 2 columns]

# %%
df2.drop('label', inplace=True, axis=1)
df2
# Out:
#                                                    Text
# 0     ইসলামের সচেতন সৈনিক,কুত্তার বাচ্চা, তোদের শিক্...
# 1                                     ধর্ম মানে অশান্তি
# 2     হিন্দু প্রকারভেদ।  রাধাকৃষ্ণ  কৃষ্ণ_কৃষ্ণ বুঝল...
# 3     সালা তুই একটা হিন্দুর বাচ্চা , নামের পরে খান ল...
# 4                  হিন্দুদের দেশ বাংলাদেশ। জয় শ্রী রাম
# ...                                                 ...
# 6526  পুরুষ তার নিজের যৌন-উত্তেজনা সামাল দেবার শিক্ষ...
# 6527  সব দোষ দিপুর! কিন্তু বিবাহিত লুচ্চা নারীগুলা এ...
# 6528    মেয়েরা অনেক লোভী তাই এদের কপালে এমনটা লেখা ছিল
# 6529               মহিলারা বেশি লোভি তাই বুজতে পারে নাই
# 6530               নারী তুই কলঙ্কিনী নারী তুই জাহান্নমী
#
# [6531 rows x 1 columns]

# %%
df3=pd.read_csv("/content/drive/MyDrive/EMNLP/last.csv")
df3
# Out:
#                                                     text
# 0      দয়াকরে জনগণকে সঠিক তথ্য দিন।যে ১৯ ক্যাটাগরির শ...
# 1         রোল মডেল তো অবশ্যই।গরীব হলেও আমরা ডিজিটাল গরীব
# 2      আসলে সরকারি খরচে চলেন তো  টের পান না, একবার জন...
# 3      বাংলাদেশ কখনোই খাদ্যে সংয়ংসম্পূর্ণ ছিলনা, যে দ...
# 4      প্রস্নপত্র ফাঁসের পর যোগ হয়েছে ফোনালাপ  ফাঁস। ...
# ...                                                  ...
# 93709                                  পালতু নাটক একটা\n
# 93710                               ফালতু, আলতু, টালতু\n
# 93711                                শালা আসোলেই পেটুক\n
# 93712                                    বেহাইয়া জামাই\n
# 93713                   নতুন অভিনয়শিল্পী। অভারএ্যাকটিং\n
#
# [93714 rows x 1 columns]

# %%
import re

input_string = "Hello, this is a test string! 1234\n5"
cleaned_string = re.sub(r'[\n]', '', input_string)

print(cleaned_string)
# Out:
# Hello, this is a test string! 12345

# %%
def clean(data):
  data = re.sub(r'[\n]', '', data)
  return data

# %%
df3["text"] = df3["text"].apply(clean)

# %%
df3
# Out:
#                                                     text
# 0      দয়াকরে জনগণকে সঠিক তথ্য দিন।যে ১৯ ক্যাটাগরির শ...
# 1         রোল মডেল তো অবশ্যই।গরীব হলেও আমরা ডিজিটাল গরীব
# 2      আসলে সরকারি খরচে চলেন তো  টের পান না, একবার জন...
# 3      বাংলাদেশ কখনোই খাদ্যে সংয়ংসম্পূর্ণ ছিলনা, যে দ...
# 4      প্রস্নপত্র ফাঁসের পর যোগ হয়েছে ফোনালাপ  ফাঁস। ...
# ...                                                  ...
# 93709                                    পালতু নাটক একটা
# 93710                                 ফালতু, আলতু, টালতু
# 93711                                  শালা আসোলেই পেটুক
# 93712                                      বেহাইয়া জামাই
# 93713                     নতুন অভিনয়শিল্পী। অভারএ্যাকটিং
#
# [93714 rows x 1 columns]

# %%
df3.to_csv("all_merged.csv")

# %%
# !cp /content/all_merged.csv /content/drive/MyDrive/EMNLP
